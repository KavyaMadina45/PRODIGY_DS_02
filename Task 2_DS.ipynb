# %%
#import movies dataset
import pandas as pd
x='/home/kavya/Downloads/imdb_top_1000.csv'
df=pd.read_csv(x)
print(df)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
#deleting nan values
import pandas as pd
x='/home/kavya/Downloads/imdb_top_1000.csv'
df=pd.read_csv(x)
print(df.isnull())
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 995        False         False          False        False    False  False
# 996        False         False          False        False    False  False
# 997        False         False          False        False    False  False
# 998        False         False          False         True    False  False
# 999        False         False          False         True    False  False
#
# ...

# %%
#drop duplicates
import pandas as pd
x='/home/kavya/Downloads/imdb_top_1000.csv'
df=pd.read_csv(x)
print(df.drop_duplicates())
print(df.dropna())
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
import pandas as pd
#importing dataset
x='/home/kavya/Downloads/imdb_top_1000.csv'
print(df[['IMDB_Rating','Meta_score']])
#fillna method used to fill the nan values with 20
print(df[['IMDB_Rating','Meta_score']].fillna(20))
#first 2 data contents
print(df[['IMDB_Rating','Meta_score']].head(2))
#correlation of rating and meta_score
print(df[['IMDB_Rating','Meta_score']].corr())
print(df.describe())
# Out:
#      IMDB_Rating  Meta_score
# 0            9.3        80.0
# 1            9.2       100.0
# 2            9.0        84.0
# 3            9.0        90.0
# 4            9.0        96.0
# ..           ...         ...
# 995          7.6        76.0
# 996          7.6        84.0
# 997          7.6        85.0
# 998          7.6        78.0
# 999          7.6        93.0
#
# [1000 rows x 2 columns]
#      IMDB_Rating  Meta_score
# 0            9.3        80.0
# 1            9.2       100.0
# 2            9.0        84.0
# 3            9.0        90.0
# 4            9.0        96.0
# ..           ...         ...
# 995          7.6        76.0
# 996          7.6        84.0
# 997          7.6        85.0
# 998          7.6        78.0
# 999          7.6        93.0
#
# [1000 rows x 2 columns]
#    IMDB_Rating  Meta_score
# 0          9.3        80.0
# 1          9.2       100.0
#              IMDB_Rating  Meta_score
# IMDB_Rating     1.000000    0.268531
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
x='/home/kavya/Downloads/imdb_top_1000.csv'
print(df[['IMDB_Rating','Meta_score','No_of_Votes']])
#univariate analysis of no of votes distribution
#histogram
plt.hist('No_of_Votes',bins=10,color="green")
plt.ylabel("no of bins")
plt.title("Visualization of distribution  of No of votes")
plt.show()

# Box Plot for No of votes
plt.figure(figsize=(10, 8))
sns.boxplot(x=df['No_of_Votes'])
plt.title('Box Plot of votes')
plt.show()
# Out:
#      IMDB_Rating  Meta_score  No_of_Votes
# 0            9.3        80.0      2343110
# 1            9.2       100.0      1620367
# 2            9.0        84.0      2303232
# 3            9.0        90.0      1129952
# 4            9.0        96.0       689845
# ..           ...         ...          ...
# 995          7.6        76.0       166544
# 996          7.6        84.0        34075
# 997          7.6        85.0        43374
# 998          7.6        78.0        26471
# 999          7.6        93.0        51853
#
# [1000 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
rating=df['IMDB_Rating'].values
# print(rating)
score=df['Meta_score'].values
#Biviraiate analysis of the rating and meta score using scatter plot
# print(year)
plt.scatter(rating,score,marker='*',color="orange")
plt.xlabel("rating")
plt.ylabel("meta score")
plt.title("Bivariate Analysis of rating and meta score in movies dataset by scatter plot")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
rating=df['IMDB_Rating'].values
# print(rating)
score=df['Meta_score'].values
# print(year)
#bivariate analysis of rating and meta score
plt.plot(rating,score,marker='p',color="navy")
plt.xlabel("rating")
plt.ylabel("meta score")
plt.title(" Bivariate analysis of rating and meta score in movies dataset by line plot")
plt.show()
plt.figure(figsize=(10, 6))
sns.violinplot(y=df['No_of_Votes'],color="black")
plt.title('Violin Plot of votes')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x='/home/kavya/Downloads/imdb_top_1000.csv'
df=pd.read_csv(x)
sns.pairplot(df)
df.hist(figsize=(10,8),bins=20,color="deeppink")
plt.show()
